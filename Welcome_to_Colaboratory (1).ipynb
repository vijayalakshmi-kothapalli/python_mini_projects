# %%
import requests

# %%
url ='https://jsonplaceholder.typicode.com/posts'

# %%
response=requests.get(url=url)

# %%
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
#   'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'},
#  {'userId': 1,
#   'id': 5,
#   'title': 'nesciunt quas odio',
#   'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'},
#  {'userId': 1,
#   'id': 6,
#   'title': 'dolorem eum magni eos aperiam quia',
#   'body': 'ut aspernatur corporis harum nihil quis provident sequi\nmollitia nobis aliquid molestiae\nperspiciatis et ea nemo ab reprehenderit accusantium quas\nvoluptate dolores velit et doloremque molestiae'},
#  {'userId': 1,
#   'id': 7,
#   'title': 'magnam facilis autem',
#   'body': 'dolore placeat quibusdam ea quo vitae\nmagni quis enim qui quis quo nemo aut saepe\nquidem repellat excepturi ut quia\nsunt ut sequi eos ea sed quas'},
#  {'userId': 1,
#   'id': 8,
#   'title': 'dolorem dolore est ipsam',
#   'body': 'dignissimos aperiam dolorem qui eum\nfacilis quibusdam animi sint suscipit qui sint possimus cum\nquaerat magni maiores excepturi\nipsam ut commodi dolor voluptatum modi aut vitae'},
#  {'userId': 1,
#   'id': 9,
#   'title': 'nesciunt iure omnis dolorem tempora et accusantium',
#   'body': 'consectetur animi nesciunt iure dolore\nenim quia ad\nveniam autem ut quam aut nobis\net est aut quod aut provident voluptas autem voluptas'},
#  {'userId': 1,
#   'id': 10,
#   'title': 'optio molestias id quia eum',
#   'body': 'quo et expedita modi cum officia vel magni\ndoloribus qui repudiandae\nvero nisi sit\nquos veniam quod sed accusamus veritatis error'},
#  {'userId': 2,
#   'id': 11,
#   'title': 'et ea vero quia laudantium autem',
#   'body': 'delectus reiciendis molestiae occaecati non minima eveniet qui voluptatibus\naccusamus in eum beatae sit\nvel qui neque voluptates ut commodi qui incidunt\nut animi commodi'},
#  {'userId': 2,
#   'id': 12,
#   'title': 'in quibusdam tempore odit est dolorem',
#   'body': 'itaque id aut magnam\npraesentium quia et ea odit et ea voluptas et\nsapiente quia nihil amet occaecati quia id voluptatem\nincidunt ea est distinctio odio'},
#  {'userId': 2,
#   'id': 13,
#   'title': 'dolorum ut in voluptas mollitia et saepe quo animi',
#   'body': 'aut dicta possimus sint mollitia voluptas commodi quo doloremque\niste corrupti reiciendis voluptatem eius rerum\nsit cumque quod eligendi laborum minima\nperferendis recusandae assumenda consectetur porro architecto ipsum ipsam'},
#  {'userId': 2,
#   'id': 14,
#   'title': 'voluptatem eligendi optio',
#   'body': 'fuga et accusamus dolorum perferendis illo voluptas\nnon doloremque neque facere\nad qui dolorum molestiae beatae\nsed aut voluptas totam sit illum'},
#  {'userId': 2,
#   'id': 15,
#   'title': 'eveniet quod temporibus',
#   'body': 'reprehenderit quos placeat\nvelit minima officia dolores impedit repudiandae molestiae nam\nvoluptas recusandae quis delectus\nofficiis harum fugiat vitae'},
#  {'userId': 2,
#   'id': 16,
#   'title': 'sint suscipit perspiciatis velit dolorum rerum ipsa laboriosam odio',
#   'body': 'suscipit nam nisi quo aperiam aut\nasperiores eos fugit maiores voluptatibus quia\nvoluptatem quis ullam qui in alias quia est\nconsequatur magni mollitia accusamus ea nisi voluptate dicta'},
#  {'userId': 2,
#   'id': 17,
#   'title': 'fugit voluptas sed molestias voluptatem provident',
#   'body': 'eos voluptas et aut odit natus earum\naspernatur fuga molestiae ullam\ndeserunt ratione qui eos\nqui nihil ratione nemo velit ut aut id quo'},
#  {'userId': 2,
#   'id': 18,
#   'title': 'voluptate et itaque vero tempora molestiae',
#   'body': 'eveniet quo quis\nlaborum totam consequatur non dolor\nut et est repudiandae\nest voluptatem vel debitis et magnam'},
#  {'userId': 2,
#   'id': 19,
#   'title': 'adipisci placeat illum aut reiciendis qui',
#   'body': 'illum quis cupiditate provident sit magnam\nea sed aut omnis\nveniam maiores ullam consequatur atque\nadipisci quo iste expedita sit quos voluptas'},
#  {'userId': 2,
#   'id': 20,
#   'title': 'doloribus ad provident suscipit at',
#   'body': 'qui consequuntur ducimus possimus quisquam amet similique\nsuscipit porro ipsam amet\neos veritatis officiis exercitationem vel fugit aut necessitatibus totam\nomnis rerum consequatur expedita quidem cumque explicabo'},
#  {'userId': 3,
#   'id': 21,
#   'title': 'asperiores ea ipsam voluptatibus modi minima quia sint',
#   'body': 'repellat aliquid praesentium dolorem quo\nsed totam minus non itaque\nnihil labore molestiae sunt dolor eveniet hic recusandae veniam\ntempora et tenetur expedita sunt'},
#  {'userId': 3,
#   'id': 22,
#   'title': 'dolor sint quo a velit explicabo quia nam',
#   'body': 'eos qui et ipsum ipsam suscipit aut\nsed omnis non odio\nexpedita earum mollitia molestiae aut atque rem suscipit\nnam impedit esse'},
#  {'userId': 3,
#   'id': 23,
#   'title': 'maxime id vitae nihil numquam',
#   'body': 'veritatis unde neque eligendi\nquae quod architecto quo neque vitae\nest illo sit tempora doloremque fugit quod\net et vel beatae sequi ullam sed tenetur perspiciatis'},
#  {'userId': 3,
#   'id': 24,
#   'title': 'autem hic labore sunt dolores incidunt',
#   'body': 'enim et ex nulla\nomnis voluptas quia qui\nvoluptatem consequatur numquam aliquam sunt\ntotam recusandae id dignissimos aut sed asperiores deserunt'},
#  {'userId': 3,
#   'id': 25,
#   'title': 'rem alias distinctio quo quis',
#   'body': 'ullam consequatur ut\nomnis quis sit vel consequuntur\nipsa eligendi ipsum molestiae et omnis error nostrum\nmolestiae illo tempore quia et distinctio'},
#  {'userId': 3,
#   'id': 26,
#   'title': 'est et quae odit qui non',
#   'body': 'similique esse doloribus nihil accusamus\nomnis dolorem fuga consequuntur reprehenderit fugit recusandae temporibus\nperspiciatis cum ut laudantium\nomnis aut molestiae vel vero'},
#  {'userId': 3,
#   'id': 27,
#   'title': 'quasi id et eos tenetur aut quo autem',
#   'body': 'eum sed dolores ipsam sint possimus debitis occaecati\ndebitis qui qui et\nut placeat enim earum aut odit facilis\nconsequatur suscipit necessitatibus rerum sed inventore temporibus consequatur'},
#  {'userId': 3,
#   'id': 28,
#   'title': 'delectus ullam et corporis nulla voluptas sequi',
#   'body': 'non et quaerat ex quae ad maiores\nmaiores recusandae totam aut blanditiis mollitia quas illo\nut voluptatibus voluptatem\nsimilique nostrum eum'},
#  {'userId': 3,
#   'id': 29,
#   'title': 'iusto eius quod necessitatibus culpa ea',
#   'body': 'odit magnam ut saepe sed non qui\ntempora atque nihil\naccusamus illum doloribus illo dolor\neligendi repudiandae odit magni similique sed cum maiores'},
#  {'userId': 3,
#   'id': 30,
#   'title': 'a quo magni similique perferendis',
#   'body': 'alias dolor cumque\nimpedit blanditiis non eveniet odio maxime\nblanditiis amet eius quis tempora quia autem rem\na provident perspiciatis quia'},
#  {'userId': 4,
#   'id': 31,
#   'title': 'ullam ut quidem id aut vel consequuntur',
#   'body': 'debitis eius sed quibusdam non quis consectetur vitae\nimpedit ut qui consequatur sed aut in\nquidem sit nostrum et maiores adipisci atque\nquaerat voluptatem adipisci repudiandae'},
#  {'userId': 4,
#   'id': 32,
#   'title': 'doloremque illum aliquid sunt',
#   'body': 'deserunt eos nobis asperiores et hic\nest debitis repellat molestiae optio\nnihil ratione ut eos beatae quibusdam distinctio maiores\nearum voluptates et aut adipisci ea maiores voluptas maxime'},
#  {'userId': 4,
#   'id': 33,
#   'title': 'qui explicabo molestiae dolorem',
#   'body': 'rerum ut et numquam laborum odit est sit\nid qui sint in\nquasi tenetur tempore aperiam et quaerat qui in\nrerum officiis sequi cumque quod'},
#  {'userId': 4,
#   'id': 34,
#   'title': 'magnam ut rerum iure',
#   'body': 'ea velit perferendis earum ut voluptatem voluptate itaque iusto\ntotam pariatur in\nnemo voluptatem voluptatem autem magni tempora minima in\nest distinctio qui assumenda accusamus dignissimos officia nesciunt nobis'},
#  {'userId': 4,
#   'id': 35,
#   'title': 'id nihil consequatur molestias animi provident',
#   'body': 'nisi error delectus possimus ut eligendi vitae\nplaceat eos harum cupiditate facilis reprehenderit voluptatem beatae\nmodi ducimus quo illum voluptas eligendi\net nobis quia fugit'},
#  {'userId': 4,
#   'id': 36,
#   'title': 'fuga nam accusamus voluptas reiciendis itaque',
#   'body': 'ad mollitia et omnis minus architecto odit\nvoluptas doloremque maxime aut non ipsa qui alias veniam\nblanditiis culpa aut quia nihil cumque facere et occaecati\nqui aspernatur quia eaque ut aperiam inventore'},
#  {'userId': 4,
#   'id': 37,
#   'title': 'provident vel ut sit ratione est',
#   'body': 'debitis et eaque non officia sed nesciunt pariatur vel\nvoluptatem iste vero et ea\nnumquam aut expedita ipsum nulla in\nvoluptates omnis consequatur aut enim officiis in quam qui'},
#  {'userId': 4,
#   'id': 38,
#   'title': 'explicabo et eos deleniti nostrum ab id repellendus',
#   'body': 'animi esse sit aut sit nesciunt assumenda eum voluptas\nquia voluptatibus provident quia necessitatibus ea\nrerum repudiandae quia voluptatem delectus fugit aut id quia\nratione optio eos iusto veniam iure'},
#  {'userId': 4,
#   'id': 39,
#   'title': 'eos dolorem iste accusantium est eaque quam',
#   'body': 'corporis rerum ducimus vel eum accusantium\nmaxime aspernatur a porro possimus iste omnis\nest in deleniti asperiores fuga aut\nvoluptas sapiente vel dolore minus voluptatem incidunt ex'},
#  {'userId': 4,
#   'id': 40,
#   'title': 'enim quo cumque',
#   'body': 'ut voluptatum aliquid illo tenetur nemo sequi quo facilis\nipsum rem optio mollitia quas\nvoluptatem eum voluptas qui\nunde omnis voluptatem iure quasi maxime voluptas nam'},
#  {'userId': 5,
#   'id': 41,
#   'title': 'non est facere',
#   'body': 'molestias id nostrum\nexcepturi molestiae dolore omnis repellendus quaerat saepe\nconsectetur iste quaerat tenetur asperiores accusamus ex ut\nnam quidem est ducimus sunt debitis saepe'},
#  {'userId': 5,
#   'id': 42,
#   'title': 'commodi ullam sint et excepturi error explicabo praesentium voluptas',
#   'body': 'odio fugit voluptatum ducimus earum autem est incidunt voluptatem\nodit reiciendis aliquam sunt sequi nulla dolorem\nnon facere repellendus voluptates quia\nratione harum vitae ut'},
#  {'userId': 5,
#   'id': 43,
#   'title': 'eligendi iste nostrum consequuntur adipisci praesentium sit beatae perferendis',
#   'body': 'similique fugit est\nillum et dolorum harum et voluptate eaque quidem\nexercitationem quos nam commodi possimus cum odio nihil nulla\ndolorum exercitationem magnam ex et a et distinctio debitis'},
#  {'userId': 5,
#   'id': 44,
#   'title': 'optio dolor molestias sit',
#   'body': 'temporibus est consectetur dolore\net libero debitis vel velit laboriosam quia\nipsum quibusdam qui itaque fuga rem aut\nea et iure quam sed maxime ut distinctio quae'},
#  {'userId': 5,
#   'id': 45,
#   'title': 'ut numquam possimus omnis eius suscipit laudantium iure',
#   'body': 'est natus reiciendis nihil possimus aut provident\nex et dolor\nrepellat pariatur est\nnobis rerum repellendus dolorem autem'},
#  {'userId': 5,
#   'id': 46,
#   'title': 'aut quo modi neque nostrum ducimus',
#   'body': 'voluptatem quisquam iste\nvoluptatibus natus officiis facilis dolorem\nquis quas ipsam\nvel et voluptatum in aliquid'},
#  {'userId': 5,
#   'id': 47,
#   'title': 'quibusdam cumque rem aut deserunt',
#   'body': 'voluptatem assumenda ut qui ut cupiditate aut impedit veniam\noccaecati nemo illum voluptatem laudantium\nmolestiae beatae rerum ea iure soluta nostrum\neligendi et voluptate'},
#  {'userId': 5,
#   'id': 48,
#   'title': 'ut voluptatem illum ea doloribus itaque eos',
#   'body': 'voluptates quo voluptatem facilis iure occaecati\nvel assumenda rerum officia et\nillum perspiciatis ab deleniti\nlaudantium repellat ad ut et autem reprehenderit'},
#  {'userId': 5,
#   'id': 49,
#   'title': 'laborum non sunt aut ut assumenda perspiciatis voluptas',
#   'body': 'inventore ab sint\nnatus fugit id nulla sequi architecto nihil quaerat\neos tenetur in in eum veritatis non\nquibusdam officiis aspernatur cumque aut commodi aut'},
#  {'userId': 5,
#   'id': 50,
#   'title': 'repellendus qui recusandae incidunt voluptates tenetur qui omnis exercitationem',
#   'body': 'error suscipit maxime adipisci consequuntur recusandae\nvoluptas eligendi et est et voluptates\nquia distinctio ab amet quaerat molestiae et vitae\nadipisci impedit sequi nesciunt quis consectetur'},
#  {'userId': 6,
#   'id': 51,
#   'title': 'soluta aliquam aperiam consequatur illo quis voluptas',
#   'body': 'sunt dolores aut doloribus\ndolore doloribus voluptates tempora et\ndoloremque et quo\ncum asperiores sit consectetur dolorem'},
#  {'userId': 6,
#   'id': 52,
#   'title': 'qui enim et consequuntur quia animi quis voluptate quibusdam',
#   'body': 'iusto est quibusdam fuga quas quaerat molestias\na enim ut sit accusamus enim\ntemporibus iusto accusantium provident architecto\nsoluta esse reprehenderit qui laborum'},
#  {'userId': 6,
#   'id': 53,
#   'title': 'ut quo aut ducimus alias',
#   'body': 'minima harum praesentium eum rerum illo dolore\nquasi exercitationem rerum nam\nporro quis neque quo\nconsequatur minus dolor quidem veritatis sunt non explicabo similique'},
#  {'userId': 6,
#   'id': 54,
#   'title': 'sit asperiores ipsam eveniet odio non quia',
#   'body': 'totam corporis dignissimos\nvitae dolorem ut occaecati accusamus\nex velit deserunt\net exercitationem vero incidunt corrupti mollitia'},
#  {'userId': 6,
#   'id': 55,
#   'title': 'sit vel voluptatem et non libero',
#   'body': 'debitis excepturi ea perferendis harum libero optio\neos accusamus cum fuga ut sapiente repudiandae\net ut incidunt omnis molestiae\nnihil ut eum odit'},
#  {'userId': 6,
#   'id': 56,
#   'title': 'qui et at rerum necessitatibus',
#   'body': 'aut est omnis dolores\nneque rerum quod ea rerum velit pariatur beatae excepturi\net provident voluptas corrupti\ncorporis harum reprehenderit dolores eligendi'},
#  {'userId': 6,
#   'id': 57,
#   'title': 'sed ab est est',
#   'body': 'at pariatur consequuntur earum quidem\nquo est laudantium soluta voluptatem\nqui ullam et est\net cum voluptas voluptatum repellat est'},
#  {'userId': 6,
#   'id': 58,
#   'title': 'voluptatum itaque dolores nisi et quasi',
#   'body': 'veniam voluptatum quae adipisci id\net id quia eos ad et dolorem\naliquam quo nisi sunt eos impedit error\nad similique veniam'},
#  {'userId': 6,
#   'id': 59,
#   'title': 'qui commodi dolor at maiores et quis id accusantium',
#   'body': 'perspiciatis et quam ea autem temporibus non voluptatibus qui\nbeatae a earum officia nesciunt dolores suscipit voluptas et\nanimi doloribus cum rerum quas et magni\net hic ut ut commodi expedita sunt'},
#  {'userId': 6,
#   'id': 60,
#   'title': 'consequatur placeat omnis quisquam quia reprehenderit fugit veritatis facere',
#   'body': 'asperiores sunt ab assumenda cumque modi velit\nqui esse omnis\nvoluptate et fuga perferendis voluptas\nillo ratione amet aut et omnis'},
#  {'userId': 7,
#   'id': 61,
#   'title': 'voluptatem doloribus consectetur est ut ducimus',
#   'body': 'ab nemo optio odio\ndelectus tenetur corporis similique nobis repellendus rerum omnis facilis\nvero blanditiis debitis in nesciunt doloribus dicta dolores\nmagnam minus velit'},
#  {'userId': 7,
#   'id': 62,
#   'title': 'beatae enim quia vel',
#   'body': 'enim aspernatur illo distinctio quae praesentium\nbeatae alias amet delectus qui voluptate distinctio\nodit sint accusantium autem omnis\nquo molestiae omnis ea eveniet optio'},
#  {'userId': 7,
#   'id': 63,
#   'title': 'voluptas blanditiis repellendus animi ducimus error sapiente et suscipit',
#   'body': 'enim adipisci aspernatur nemo\nnumquam omnis facere dolorem dolor ex quis temporibus incidunt\nab delectus culpa quo reprehenderit blanditiis asperiores\naccusantium ut quam in voluptatibus voluptas ipsam dicta'},
#  {'userId': 7,
#   'id': 64,
#   'title': 'et fugit quas eum in in aperiam quod',
#   'body': 'id velit blanditiis\neum ea voluptatem\nmolestiae sint occaecati est eos perspiciatis\nincidunt a error provident eaque aut aut qui'},
#  {'userId': 7,
#   'id': 65,
#   'title': 'consequatur id enim sunt et et',
#   'body': 'voluptatibus ex esse\nsint explicabo est aliquid cumque adipisci fuga repellat labore\nmolestiae corrupti ex saepe at asperiores et perferendis\nnatus id esse incidunt pariatur'},
#  {'userId': 7,
#   'id': 66,
#   'title': 'repudiandae ea animi iusto',
#   'body': 'officia veritatis tenetur vero qui itaque\nsint non ratione\nsed et ut asperiores iusto eos molestiae nostrum\nveritatis quibusdam et nemo iusto saepe'},
#  {'userId': 7,
#   'id': 67,
#   'title': 'aliquid eos sed fuga est maxime repellendus',
#   'body': 'reprehenderit id nostrum\nvoluptas doloremque pariatur sint et accusantium quia quod aspernatur\net fugiat amet\nnon sapiente et consequatur necessitatibus molestiae'},
#  {'userId': 7,
#   'id': 68,
#   'title': 'odio quis facere architecto reiciendis optio',
#   'body': 'magnam molestiae perferendis quisquam\nqui cum reiciendis\nquaerat animi amet hic inventore\nea quia deleniti quidem saepe porro velit'},
#  {'userId': 7,
#   'id': 69,
#   'title': 'fugiat quod pariatur odit minima',
#   'body': 'officiis error culpa consequatur modi asperiores et\ndolorum assumenda voluptas et vel qui aut vel rerum\nvoluptatum quisquam perspiciatis quia rerum consequatur totam quas\nsequi commodi repudiandae asperiores et saepe a'},
#  {'userId': 7,
#   'id': 70,
#   'title': 'voluptatem laborum magni',
#   'body': 'sunt repellendus quae\nest asperiores aut deleniti esse accusamus repellendus quia aut\nquia dolorem unde\neum tempora esse dolore'},
#  {'userId': 8,
#   'id': 71,
#   'title': 'et iusto veniam et illum aut fuga',
#   'body': 'occaecati a doloribus\niste saepe consectetur placeat eum voluptate dolorem et\nqui quo quia voluptas\nrerum ut id enim velit est perferendis'},
#  {'userId': 8,
#   'id': 72,
#   'title': 'sint hic doloribus consequatur eos non id',
#   'body': 'quam occaecati qui deleniti consectetur\nconsequatur aut facere quas exercitationem aliquam hic voluptas\nneque id sunt ut aut accusamus\nsunt consectetur expedita inventore velit'},
#  {'userId': 8,
#   'id': 73,
#   'title': 'consequuntur deleniti eos quia temporibus ab aliquid at',
#   'body': 'voluptatem cumque tenetur consequatur expedita ipsum nemo quia explicabo\naut eum minima consequatur\ntempore cumque quae est et\net in consequuntur voluptatem voluptates aut'},
#  {'userId': 8,
#   'id': 74,
#   'title': 'enim unde ratione doloribus quas enim ut sit sapiente',
#   'body': 'odit qui et et necessitatibus sint veniam\nmollitia amet doloremque molestiae commodi similique magnam et quam\nblanditiis est itaque\nquo et tenetur ratione occaecati molestiae tempora'},
#  {'userId': 8,
#   'id': 75,
#   'title': 'dignissimos eum dolor ut enim et delectus in',
#   'body': 'commodi non non omnis et voluptas sit\nautem aut nobis magnam et sapiente voluptatem\net laborum repellat qui delectus facilis temporibus\nrerum amet et nemo voluptate expedita adipisci error dolorem'},
#  {'userId': 8,
#   'id': 76,
#   'title': 'doloremque officiis ad et non perferendis',
#   'body': 'ut animi facere\ntotam iusto tempore\nmolestiae eum aut et dolorem aperiam\nquaerat recusandae totam odio'},
#  {'userId': 8,
#   'id': 77,
#   'title': 'necessitatibus quasi exercitationem odio',
#   'body': 'modi ut in nulla repudiandae dolorum nostrum eos\naut consequatur omnis\nut incidunt est omnis iste et quam\nvoluptates sapiente aliquam asperiores nobis amet corrupti repudiandae provident'},
#  {'userId': 8,
#   'id': 78,
#   'title': 'quam voluptatibus rerum veritatis',
#   'body': 'nobis facilis odit tempore cupiditate quia\nassumenda doloribus rerum qui ea\nillum et qui totam\naut veniam repellendus'},
#  {'userId': 8,
#   'id': 79,
#   'title': 'pariatur consequatur quia magnam autem omnis non amet',
#   'body': 'libero accusantium et et facere incidunt sit dolorem\nnon excepturi qui quia sed laudantium\nquisquam molestiae ducimus est\nofficiis esse molestiae iste et quos'},
#  {'userId': 8,
#   'id': 80,
#   'title': 'labore in ex et explicabo corporis aut quas',
#   'body': 'ex quod dolorem ea eum iure qui provident amet\nquia qui facere excepturi et repudiandae\nasperiores molestias provident\nminus incidunt vero fugit rerum sint sunt excepturi provident'},
#  {'userId': 9,
#   'id': 81,
#   'title': 'tempora rem veritatis voluptas quo dolores vero',
#   'body': 'facere qui nesciunt est voluptatum voluptatem nisi\nsequi eligendi necessitatibus ea at rerum itaque\nharum non ratione velit laboriosam quis consequuntur\nex officiis minima doloremque voluptas ut aut'},
#  {'userId': 9,
#   'id': 82,
#   'title': 'laudantium voluptate suscipit sunt enim enim',
#   'body': 'ut libero sit aut totam inventore sunt\nporro sint qui sunt molestiae\nconsequatur cupiditate qui iste ducimus adipisci\ndolor enim assumenda soluta laboriosam amet iste delectus hic'},
#  {'userId': 9,
#   'id': 83,
#   'title': 'odit et voluptates doloribus alias odio et',
#   'body': 'est molestiae facilis quis tempora numquam nihil qui\nvoluptate sapiente consequatur est qui\nnecessitatibus autem aut ipsa aperiam modi dolore numquam\nreprehenderit eius rem quibusdam'},
#  {'userId': 9,
#   'id': 84,
#   'title': 'optio ipsam molestias necessitatibus occaecati facilis veritatis dolores aut',
#   'body': 'sint molestiae magni a et quos\neaque et quasi\nut rerum debitis similique veniam\nrecusandae dignissimos dolor incidunt consequatur odio'},
#  {'userId': 9,
#   'id': 85,
#   'title': 'dolore veritatis porro provident adipisci blanditiis et sunt',
#   'body': 'similique sed nisi voluptas iusto omnis\nmollitia et quo\nassumenda suscipit officia magnam sint sed tempora\nenim provident pariatur praesentium atque animi amet ratione'},
#  {'userId': 9,
#   'id': 86,
#   'title': 'placeat quia et porro iste',
#   'body': 'quasi excepturi consequatur iste autem temporibus sed molestiae beatae\net quaerat et esse ut\nvoluptatem occaecati et vel explicabo autem\nasperiores pariatur deserunt optio'},
#  {'userId': 9,
#   'id': 87,
#   'title': 'nostrum quis quasi placeat',
#   'body': 'eos et molestiae\nnesciunt ut a\ndolores perspiciatis repellendus repellat aliquid\nmagnam sint rem ipsum est'},
#  {'userId': 9,
#   'id': 88,
#   'title': 'sapiente omnis fugit eos',
#   'body': 'consequatur omnis est praesentium\nducimus non iste\nneque hic deserunt\nvoluptatibus veniam cum et rerum sed'},
#  {'userId': 9,
#   'id': 89,
#   'title': 'sint soluta et vel magnam aut ut sed qui',
#   'body': 'repellat aut aperiam totam temporibus autem et\narchitecto magnam ut\nconsequatur qui cupiditate rerum quia soluta dignissimos nihil iure\ntempore quas est'},
#  {'userId': 9,
#   'id': 90,
#   'title': 'ad iusto omnis odit dolor voluptatibus',
#   'body': 'minus omnis soluta quia\nqui sed adipisci voluptates illum ipsam voluptatem\neligendi officia ut in\neos soluta similique molestias praesentium blanditiis'},
#  {'userId': 10,
#   'id': 91,
#   'title': 'aut amet sed',
#   'body': 'libero voluptate eveniet aperiam sed\nsunt placeat suscipit molestias\nsimilique fugit nam natus\nexpedita consequatur consequatur dolores quia eos et placeat'},
#  {'userId': 10,
#   'id': 92,
#   'title': 'ratione ex tenetur perferendis',
#   'body': 'aut et excepturi dicta laudantium sint rerum nihil\nlaudantium et at\na neque minima officia et similique libero et\ncommodi voluptate qui'},
#  {'userId': 10,
#   'id': 93,
#   'title': 'beatae soluta recusandae',
#   'body': 'dolorem quibusdam ducimus consequuntur dicta aut quo laboriosam\nvoluptatem quis enim recusandae ut sed sunt\nnostrum est odit totam\nsit error sed sunt eveniet provident qui nulla'},
#  {'userId': 10,
#   'id': 94,
#   'title': 'qui qui voluptates illo iste minima',
#   'body': 'aspernatur expedita soluta quo ab ut similique\nexpedita dolores amet\nsed temporibus distinctio magnam saepe deleniti\nomnis facilis nam ipsum natus sint similique omnis'},
#  {'userId': 10,
#   'id': 95,
#   'title': 'id minus libero illum nam ad officiis',
#   'body': 'earum voluptatem facere provident blanditiis velit laboriosam\npariatur accusamus odio saepe\ncumque dolor qui a dicta ab doloribus consequatur omnis\ncorporis cupiditate eaque assumenda ad nesciunt'},
#  {'userId': 10,
#   'id': 96,
#   'title': 'quaerat velit veniam amet cupiditate aut numquam ut sequi',
#   'body': 'in non odio excepturi sint eum\nlabore voluptates vitae quia qui et\ninventore itaque rerum\nveniam non exercitationem delectus aut'},
#  {'userId': 10,
#   'id': 97,
#   'title': 'quas fugiat ut perspiciatis vero provident',
#   'body': 'eum non blanditiis soluta porro quibusdam voluptas\nvel voluptatem qui placeat dolores qui velit aut\nvel inventore aut cumque culpa explicabo aliquid at\nperspiciatis est et voluptatem dignissimos dolor itaque sit nam'},
#  {'userId': 10,
#   'id': 98,
#   'title': 'laboriosam dolor voluptates',
#   'body': 'doloremque ex facilis sit sint culpa\nsoluta assumenda eligendi non ut eius\nsequi ducimus vel quasi\nveritatis est dolores'},
#  {'userId': 10,
#   'id': 99,
#   'title': 'temporibus sit alias delectus eligendi possimus magni',
#   'body': 'quo deleniti praesentium dicta non quod\naut est molestias\nmolestias et officia quis nihil\nitaque dolorem quia'},
#  {'userId': 10,
#   'id': 100,
#   'title': 'at nam consequatur ea labore ea harum',
#   'body': 'cupiditate quo est a modi nesciunt soluta\nipsa voluptas error itaque dicta in\nautem qui minus magnam et distinctio eum\naccusamus ratione error aut'}]

# %%
type(response.json())
# Out:
# list

# %%
for _ in response.json():
     print(f'postnumber is{_["id"]}')
# Out:
# postnumber is1
# postnumber is2
# postnumber is3
# postnumber is4
# postnumber is5
# postnumber is6
# postnumber is7
# postnumber is8
# postnumber is9
# postnumber is10
# postnumber is11
# postnumber is12
# postnumber is13
# postnumber is14
# postnumber is15
# postnumber is16
# postnumber is17
# postnumber is18
# postnumber is19
# postnumber is20
# postnumber is21
# postnumber is22
# postnumber is23
# postnumber is24
# postnumber is25
# postnumber is26
# postnumber is27
# postnumber is28
# postnumber is29
# postnumber is30
# postnumber is31
# postnumber is32
# postnumber is33
# postnumber is34
# postnumber is35
# postnumber is36
# postnumber is37
# postnumber is38
# postnumber is39
# postnumber is40
# postnumber is41
# postnumber is42
# postnumber is43
# postnumber is44
# postnumber is45
# postnumber is46
# postnumber is47
# postnumber is48
# postnumber is49
# postnumber is50
# postnumber is51
# postnumber is52
# postnumber is53
# postnumber is54
# postnumber is55
# postnumber is56
# postnumber is57
# postnumber is58
# postnumber is59
# postnumber is60
# postnumber is61
# postnumber is62
# postnumber is63
# postnumber is64
# postnumber is65
# postnumber is66
# postnumber is67
# postnumber is68
# postnumber is69
# postnumber is70
# postnumber is71
# postnumber is72
# postnumber is73
# postnumber is74
# postnumber is75
# postnumber is76
# postnumber is77
# postnumber is78
# postnumber is79
# postnumber is80
# postnumber is81
# postnumber is82
# postnumber is83
# postnumber is84
# postnumber is85
# postnumber is86
# postnumber is87
# postnumber is88
# postnumber is89
# postnumber is90
# postnumber is91
# postnumber is92
# postnumber is93
# postnumber is94
# postnumber is95
# postnumber is96
# postnumber is97
# postnumber is98
# postnumber is99
# postnumber is100

# %%
url='https://api.github.com/search/repositories'

# %%
parms={
    'q':'pandas+language:python',
    'sort':'stars',
    'order':'desc'}

# %%
response=requests.get(url=url,params=parms)

# %%
response.json()
# Out:
# {'total_count': 658,
#  'incomplete_results': False,
#  'items': [{'id': 106368971,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMDYzNjg5NzE=',
#    'name': 'Cheatsheets',
#    'full_name': 'sentientmachine/Cheatsheets',
#    'private': False,
#    'owner': {'login': 'sentientmachine',
#     'id': 330247,
#     'node_id': 'MDQ6VXNlcjMzMDI0Nw==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/330247?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sentientmachine',
#     'html_url': 'https://github.com/sentientmachine',
#     'followers_url': 'https://api.github.com/users/sentientmachine/followers',
#     'following_url': 'https://api.github.com/users/sentientmachine/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sentientmachine/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sentientmachine/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sentientmachine/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sentientmachine/orgs',
#     'repos_url': 'https://api.github.com/users/sentientmachine/repos',
#     'events_url': 'https://api.github.com/users/sentientmachine/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sentientmachine/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/sentientmachine/Cheatsheets',
#    'description': 'Evolving Cheatsheets for computer languages/software/OS like Python, Numpy, Pandas, Java, Linux, Terminal, Gentoo',
#    'fork': False,
#    'url': 'https://api.github.com/repos/sentientmachine/Cheatsheets',
#    'forks_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/forks',
#    'keys_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/teams',
#    'hooks_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/events',
#    'assignees_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/tags',
#    'blobs_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/languages',
#    'stargazers_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/subscription',
#    'commits_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/merges',
#    'archive_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/downloads',
#    'issues_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sentientmachine/Cheatsheets/deployments',
#    'created_at': '2017-10-10T04:38:27Z',
#    'updated_at': '2025-01-26T12:08:21Z',
#    'pushed_at': '2024-10-10T18:11:44Z',
#    'git_url': 'git://github.com/sentientmachine/Cheatsheets.git',
#    'ssh_url': 'git@github.com:sentientmachine/Cheatsheets.git',
#    'clone_url': 'https://github.com/sentientmachine/Cheatsheets.git',
#    'svn_url': 'https://github.com/sentientmachine/Cheatsheets',
#    'homepage': '',
#    'size': 34621,
#    'stargazers_count': 92,
#    'watchers_count': 92,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['numpy', 'pandas', 'python3'],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 0,
#    'watchers': 92,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 461768724,
#    'node_id': 'R_kgDOG4YIFA',
#    'name': 'HealthChatbot',
#    'full_name': 'shreyasharma04/HealthChatbot',
#    'private': False,
#    'owner': {'login': 'shreyasharma04',
#     'id': 70131160,
#     'node_id': 'MDQ6VXNlcjcwMTMxMTYw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/70131160?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/shreyasharma04',
#     'html_url': 'https://github.com/shreyasharma04',
#     'followers_url': 'https://api.github.com/users/shreyasharma04/followers',
#     'following_url': 'https://api.github.com/users/shreyasharma04/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/shreyasharma04/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/shreyasharma04/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/shreyasharma04/subscriptions',
#     'organizations_url': 'https://api.github.com/users/shreyasharma04/orgs',
#     'repos_url': 'https://api.github.com/users/shreyasharma04/repos',
#     'events_url': 'https://api.github.com/users/shreyasharma04/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/shreyasharma04/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/shreyasharma04/HealthChatbot',
#    'description': '🤖 HealthCare ChatBot Major -1 (4th year - 7th semester)  Health Care Chat-Bot is a Healthcare Domain Chatbot to simulate the predictions of a General Physician.  ChatBot can be described as software that can chat with people using artificial intelligence. These software are used to perform tasks such as quickly responding to users, informing them, helping to purchase products and providing better service to customers. We have made a healthcare based chatbot.  The three main areas where chatbots can be used are diagnostics, patient engagement outside medical facilities, and mental health. In our major we are working on diagnostic.  📃 Brief A chatbot is an artificially intelligent creature which can converse with humans. This could be text-based, or a spoken conversation. In our project we will be using Python as it is currently the most popular language for creating an AI chatbot. In the middle of AI chatbot, architecture is the Natural Language Processing (NLP) layer.  This project aims to build an user-friendly healthcare chatbot which facilitates the job of a healthcare provider and helps improve their performance by interacting with users in a human-like way.  Through chatbots one can communicate with text or voice interface and get reply through artificial intelligence  Typically, a chat bot will communicate with a real person. Chat bots are used in applications such as E-commerce customer service, Call centres, Internet gaming,etc.  Chatbots are programs built to automatically engage with received messages. Chatbots can be programmed to respond the same way each time, to respond differently to messages containing certain keywords and even to use machine learning to adapt their responses to fit the situation.  A developing number of hospitals, nursing homes, and even private centres, presently utilize online Chatbots for human services on their sites. These bots connect with potential patients visiting the site, helping them discover specialists, booking their appointments, and getting them access to the correct treatment.  In any case, the utilization of artificial intelligence in an industry where individuals’ lives could be in question, still starts misgivings in individuals. It brings up issues about whether the task mentioned above ought to be assigned to human staff. This healthcare chatbot system will help hospitals to provide healthcare support online 24 x 7, it answers deep as well as general questions. It also helps to generate leads and automatically delivers the information of leads to sales. By asking the questions in series it helps patients by guiding what exactly he/she is looking for.  📜 Problem Statement During the pandemic, it is more important than ever to get your regular check-ups and to continue to take prescription medications. The healthier you are, the more likely you are to recover quickly from an illness.  In this time patients or health care workers within their practice, providers are deferring elective and preventive visits, such as annual physicals. For some, it is not possible to consult online. In this case, to avoid false information, our project can be of help.  📇 Features Register Screen. Sign-in Screen. Generates database for user login system. Offers you a GUI Based Chatbot for patients for diagnosing. [A pragmatic Approach for Diagnosis] Reccomends an appropriate doctor to you for the following symptom. 📜 Modules Used Our program uses a number of python modules to work properly:  tkinter os webbrowser numpy pandas matplotlib 📃 Algorithm We have used Decision tree for our health care based chat bot.  Decision Tree is a Supervised learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome.It usually mimic hu ...
#    'fork': False,
#    'url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot',
#    'forks_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/forks',
#    'keys_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/teams',
#    'hooks_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/hooks',
#    'issue_events_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/events',
#    'assignees_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/tags',
#    'blobs_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/languages',
#    'stargazers_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/stargazers',
#    'contributors_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/contributors',
#    'subscribers_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/subscribers',
#    'subscription_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/subscription',
#    'commits_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/merges',
#    'archive_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/downloads',
#    'issues_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/shreyasharma04/HealthChatbot/deployments',
#    'created_at': '2022-02-21T08:27:25Z',
#    'updated_at': '2025-02-03T09:02:55Z',
#    'pushed_at': '2022-02-21T08:29:12Z',
#    'git_url': 'git://github.com/shreyasharma04/HealthChatbot.git',
#    'ssh_url': 'git@github.com:shreyasharma04/HealthChatbot.git',
#    'clone_url': 'https://github.com/shreyasharma04/HealthChatbot.git',
#    'svn_url': 'https://github.com/shreyasharma04/HealthChatbot',
#    'homepage': None,
#    'size': 62,
#    'stargazers_count': 91,
#    'watchers_count': 91,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 17,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 17,
#    'open_issues': 0,
#    'watchers': 91,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 334348676,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMzQzNDg2NzY=',
#    'name': 'Applied-Data-Science-with-Python-Specialization',
#    'full_name': 'yonycherkos/Applied-Data-Science-with-Python-Specialization',
#    'private': False,
#    'owner': {'login': 'yonycherkos',
#     'id': 45253598,
#     'node_id': 'MDQ6VXNlcjQ1MjUzNTk4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/45253598?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/yonycherkos',
#     'html_url': 'https://github.com/yonycherkos',
#     'followers_url': 'https://api.github.com/users/yonycherkos/followers',
#     'following_url': 'https://api.github.com/users/yonycherkos/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/yonycherkos/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/yonycherkos/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/yonycherkos/subscriptions',
#     'organizations_url': 'https://api.github.com/users/yonycherkos/orgs',
#     'repos_url': 'https://api.github.com/users/yonycherkos/repos',
#     'events_url': 'https://api.github.com/users/yonycherkos/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/yonycherkos/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/yonycherkos/Applied-Data-Science-with-Python-Specialization',
#    'description': 'The 5 courses in this University of Michigan specialization introduce learners to data science through the python programming language. This skills-based specialization is intended for learners who have a basic python or programming background, and want to apply statistical, machine learning, information visualization, text analysis, and social network analysis techniques through popular python toolkits such as pandas, matplotlib, scikit-learn, nltk, and networkx to gain insight into their data.  Introduction to Data Science in Python (course 1), Applied Plotting, Charting & Data Representation in Python (course 2), and Applied Machine Learning in Python (course 3) should be taken in order and prior to any other course in the specialization.  After completing those, courses 4 and 5 can be taken in any order.  All 5 are required to earn a certificate.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization',
#    'forks_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/forks',
#    'keys_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/teams',
#    'hooks_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/hooks',
#    'issue_events_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/events',
#    'assignees_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/tags',
#    'blobs_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/languages',
#    'stargazers_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/stargazers',
#    'contributors_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/contributors',
#    'subscribers_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/subscribers',
#    'subscription_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/subscription',
#    'commits_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/merges',
#    'archive_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/downloads',
#    'issues_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/yonycherkos/Applied-Data-Science-with-Python-Specialization/deployments',
#    'created_at': '2021-01-30T06:51:36Z',
#    'updated_at': '2025-02-01T00:40:30Z',
#    'pushed_at': '2022-01-04T16:46:38Z',
#    'git_url': 'git://github.com/yonycherkos/Applied-Data-Science-with-Python-Specialization.git',
#    'ssh_url': 'git@github.com:yonycherkos/Applied-Data-Science-with-Python-Specialization.git',
#    'clone_url': 'https://github.com/yonycherkos/Applied-Data-Science-with-Python-Specialization.git',
#    'svn_url': 'https://github.com/yonycherkos/Applied-Data-Science-with-Python-Specialization',
#    'homepage': None,
#    'size': 30812,
#    'stargazers_count': 75,
#    'watchers_count': 75,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 65,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 65,
#    'open_issues': 1,
#    'watchers': 75,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 337923098,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMzc5MjMwOTg=',
#    'name': 'Python-Basic-programs',
#    'full_name': 'sanusanth/Python-Basic-programs',
#    'private': False,
#    'owner': {'login': 'sanusanth',
#     'id': 66163152,
#     'node_id': 'MDQ6VXNlcjY2MTYzMTUy',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/66163152?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sanusanth',
#     'html_url': 'https://github.com/sanusanth',
#     'followers_url': 'https://api.github.com/users/sanusanth/followers',
#     'following_url': 'https://api.github.com/users/sanusanth/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sanusanth/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sanusanth/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sanusanth/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sanusanth/orgs',
#     'repos_url': 'https://api.github.com/users/sanusanth/repos',
#     'events_url': 'https://api.github.com/users/sanusanth/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sanusanth/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/sanusanth/Python-Basic-programs',
#    'description': "What is Python? Executive Summary Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms, and can be freely distributed.   Often, programmers fall in love with Python because of the increased productivity it provides. Since there is no compilation step, the edit-test-debug cycle is incredibly fast. Debugging Python programs is easy: a bug or bad input will never cause a segmentation fault. Instead, when the interpreter discovers an error, it raises an exception. When the program doesn't catch the exception, the interpreter prints a stack trace. A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions, setting breakpoints, stepping through the code a line at a time, and so on. The debugger is written in Python itself, testifying to Python's introspective power. On the other hand, often the quickest way to debug a program is to add a few print statements to the source: the fast edit-test-debug cycle makes this simple approach very effective.  What is Python? Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.  It is used for:  web development (server-side), software development, mathematics, system scripting.  What can Python do?  Python can be used on a server to create web applications. Python can be used alongside software to create workflows. Python can connect to database systems. It can also read and modify files. Python can be used to handle big data and perform complex mathematics. Python can be used for rapid prototyping, or for production-ready software development.  Why Python?  Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc). Python has a simple syntax similar to the English language. Python has syntax that allows developers to write programs with fewer lines than some other programming languages. Python runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick. Python can be treated in a procedural way, an object-oriented way or a functional way.  Good to know  The most recent major version of Python is Python 3, which we shall be using in this tutorial. However, Python 2, although not being updated with anything other than security updates, is still quite popular. In this tutorial Python will be written in a text editor. It is possible to write Python in an Integrated Development Environment, such as Thonny, Pycharm, Netbeans or Eclipse which are particularly useful when managing larger collections of Python files.  Python Syntax compared to other programming languages  Python was designed for readability, and has some similarities to the English language with influence from mathematics. Python uses new lines to complete a command, as opposed to other programming languages which often use semicolons or parentheses. Python relies on indentation, using whitespace, to define scope; such as the scope of loops, functions and classes. Other programming languages often use curly-brackets for this purpose.  Applications for Python  Python is used in many application domains. Here's a sampling.  The Python Package Index lists thousands of third party modules for Python.  Web and Internet Development  Python offers many choices for web development:  Frameworks such as Django and Pyramid ...
#    'fork': False,
#    'url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs',
#    'forks_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/forks',
#    'keys_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/teams',
#    'hooks_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/events',
#    'assignees_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/tags',
#    'blobs_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/languages',
#    'stargazers_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/subscription',
#    'commits_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/merges',
#    'archive_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/downloads',
#    'issues_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sanusanth/Python-Basic-programs/deployments',
#    'created_at': '2021-02-11T03:50:51Z',
#    'updated_at': '2025-01-28T23:22:27Z',
#    'pushed_at': '2023-02-15T17:37:02Z',
#    'git_url': 'git://github.com/sanusanth/Python-Basic-programs.git',
#    'ssh_url': 'git@github.com:sanusanth/Python-Basic-programs.git',
#    'clone_url': 'https://github.com/sanusanth/Python-Basic-programs.git',
#    'svn_url': 'https://github.com/sanusanth/Python-Basic-programs',
#    'homepage': None,
#    'size': 731,
#    'stargazers_count': 65,
#    'watchers_count': 65,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 14,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 14,
#    'open_issues': 2,
#    'watchers': 65,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 401964191,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MDE5NjQxOTE=',
#    'name': 'JigsawDataset',
#    'full_name': 'microsoft/JigsawDataset',
#    'private': False,
#    'owner': {'login': 'microsoft',
#     'id': 6154722,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/microsoft',
#     'html_url': 'https://github.com/microsoft',
#     'followers_url': 'https://api.github.com/users/microsoft/followers',
#     'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#     'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#     'repos_url': 'https://api.github.com/users/microsoft/repos',
#     'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/microsoft/JigsawDataset',
#    'description': 'Jigsaw Dataset: Natural language to Python Pandas code',
#    'fork': False,
#    'url': 'https://api.github.com/repos/microsoft/JigsawDataset',
#    'forks_url': 'https://api.github.com/repos/microsoft/JigsawDataset/forks',
#    'keys_url': 'https://api.github.com/repos/microsoft/JigsawDataset/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/microsoft/JigsawDataset/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/microsoft/JigsawDataset/teams',
#    'hooks_url': 'https://api.github.com/repos/microsoft/JigsawDataset/hooks',
#    'issue_events_url': 'https://api.github.com/repos/microsoft/JigsawDataset/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/microsoft/JigsawDataset/events',
#    'assignees_url': 'https://api.github.com/repos/microsoft/JigsawDataset/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/microsoft/JigsawDataset/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/microsoft/JigsawDataset/tags',
#    'blobs_url': 'https://api.github.com/repos/microsoft/JigsawDataset/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/microsoft/JigsawDataset/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/microsoft/JigsawDataset/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/microsoft/JigsawDataset/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/microsoft/JigsawDataset/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/microsoft/JigsawDataset/languages',
#    'stargazers_url': 'https://api.github.com/repos/microsoft/JigsawDataset/stargazers',
#    'contributors_url': 'https://api.github.com/repos/microsoft/JigsawDataset/contributors',
#    'subscribers_url': 'https://api.github.com/repos/microsoft/JigsawDataset/subscribers',
#    'subscription_url': 'https://api.github.com/repos/microsoft/JigsawDataset/subscription',
#    'commits_url': 'https://api.github.com/repos/microsoft/JigsawDataset/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/microsoft/JigsawDataset/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/microsoft/JigsawDataset/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/microsoft/JigsawDataset/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/microsoft/JigsawDataset/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/microsoft/JigsawDataset/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/microsoft/JigsawDataset/merges',
#    'archive_url': 'https://api.github.com/repos/microsoft/JigsawDataset/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/microsoft/JigsawDataset/downloads',
#    'issues_url': 'https://api.github.com/repos/microsoft/JigsawDataset/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/microsoft/JigsawDataset/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/microsoft/JigsawDataset/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/microsoft/JigsawDataset/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/microsoft/JigsawDataset/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/microsoft/JigsawDataset/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/microsoft/JigsawDataset/deployments',
#    'created_at': '2021-09-01T07:02:48Z',
#    'updated_at': '2024-06-21T08:29:54Z',
#    'pushed_at': '2022-12-18T00:06:13Z',
#    'git_url': 'git://github.com/microsoft/JigsawDataset.git',
#    'ssh_url': 'git@github.com:microsoft/JigsawDataset.git',
#    'clone_url': 'https://github.com/microsoft/JigsawDataset.git',
#    'svn_url': 'https://github.com/microsoft/JigsawDataset',
#    'homepage': '',
#    'size': 60,
#    'stargazers_count': 53,
#    'watchers_count': 53,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 10,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 10,
#    'open_issues': 2,
#    'watchers': 53,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 157069546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNTcwNjk1NDY=',
#    'name': 'Python-for-Data-Science-and-Machine-Learning-Bootcamp',
#    'full_name': 'abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp',
#    'private': False,
#    'owner': {'login': 'abhiwalia15',
#     'id': 29868016,
#     'node_id': 'MDQ6VXNlcjI5ODY4MDE2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/29868016?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/abhiwalia15',
#     'html_url': 'https://github.com/abhiwalia15',
#     'followers_url': 'https://api.github.com/users/abhiwalia15/followers',
#     'following_url': 'https://api.github.com/users/abhiwalia15/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/abhiwalia15/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/abhiwalia15/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/abhiwalia15/subscriptions',
#     'organizations_url': 'https://api.github.com/users/abhiwalia15/orgs',
#     'repos_url': 'https://api.github.com/users/abhiwalia15/repos',
#     'events_url': 'https://api.github.com/users/abhiwalia15/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/abhiwalia15/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp',
#    'description': 'program with Python, how to create amazing data visualizations, and how to use Machine Learning with Python! Here a just a few of the topics we will be learning:  Programming with Python NumPy with Python Using pandas Data Frames to solve complex tasks Use pandas to handle Excel Files Web scraping with python Connect Python to SQL Use matplotlib and seaborn for data visualizations Use plotly for interactive visualizations Machine Learning with SciKit Learn, including: Linear Regression K Nearest Neighbors K Means Clustering Decision Trees Random Forests Natural Language Processing Neural Nets and Deep Learning Support Vector Machines and much, much more!',
#    'fork': False,
#    'url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp',
#    'forks_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/forks',
#    'keys_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/teams',
#    'hooks_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/hooks',
#    'issue_events_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/events',
#    'assignees_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/tags',
#    'blobs_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/languages',
#    'stargazers_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/stargazers',
#    'contributors_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/contributors',
#    'subscribers_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/subscribers',
#    'subscription_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/subscription',
#    'commits_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/merges',
#    'archive_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/downloads',
#    'issues_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp/deployments',
#    'created_at': '2018-11-11T10:40:14Z',
#    'updated_at': '2024-11-08T21:29:15Z',
#    'pushed_at': '2019-05-26T06:35:53Z',
#    'git_url': 'git://github.com/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp.git',
#    'ssh_url': 'git@github.com:abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp.git',
#    'clone_url': 'https://github.com/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp.git',
#    'svn_url': 'https://github.com/abhiwalia15/Python-for-Data-Science-and-Machine-Learning-Bootcamp',
#    'homepage': None,
#    'size': 106375,
#    'stargazers_count': 38,
#    'watchers_count': 38,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
# ...
#    'compare_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/merges',
#    'archive_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/downloads',
#    'issues_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/gautamik2030/Python-Specialization-Course-by-University-of-Michigan/deployments',
#    'created_at': '2020-07-06T06:13:14Z',
#    'updated_at': '2021-01-28T08:56:24Z',
#    'pushed_at': '2020-09-19T08:10:38Z',
#    'git_url': 'git://github.com/gautamik2030/Python-Specialization-Course-by-University-of-Michigan.git',
#    'ssh_url': 'git@github.com:gautamik2030/Python-Specialization-Course-by-University-of-Michigan.git',
#    'clone_url': 'https://github.com/gautamik2030/Python-Specialization-Course-by-University-of-Michigan.git',
#    'svn_url': 'https://github.com/gautamik2030/Python-Specialization-Course-by-University-of-Michigan',
#    'homepage': None,
#    'size': 103,
#    'stargazers_count': 4,
#    'watchers_count': 4,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 4,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 254818144,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNTQ4MTgxNDQ=',
#    'name': 'Twitter-Spam-detection',
#    'full_name': 'mitulprajapati/Twitter-Spam-detection',
#    'private': False,
#    'owner': {'login': 'mitulprajapati',
#     'id': 63492181,
#     'node_id': 'MDQ6VXNlcjYzNDkyMTgx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/63492181?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/mitulprajapati',
#     'html_url': 'https://github.com/mitulprajapati',
#     'followers_url': 'https://api.github.com/users/mitulprajapati/followers',
#     'following_url': 'https://api.github.com/users/mitulprajapati/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/mitulprajapati/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/mitulprajapati/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/mitulprajapati/subscriptions',
#     'organizations_url': 'https://api.github.com/users/mitulprajapati/orgs',
#     'repos_url': 'https://api.github.com/users/mitulprajapati/repos',
#     'events_url': 'https://api.github.com/users/mitulprajapati/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/mitulprajapati/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/mitulprajapati/Twitter-Spam-detection',
#    'description': 'The research project based on the detection of spammers on Twitter social media. Classification technique used for predicting spammers. Performance measured by the different machine learning algorithms and achieved the highest accuracy of 98%. The project goal was to analyse spammers behaviours from the dataset and proposed a classification model for prediction of spam or non-spam users. Python programming language and Nltk (Natural language toolkit), Scikit-learn, Pandas, Numpy, Matplotlib - libraries used for execution.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection',
#    'forks_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/forks',
#    'keys_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/teams',
#    'hooks_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/hooks',
#    'issue_events_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/events',
#    'assignees_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/tags',
#    'blobs_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/languages',
#    'stargazers_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/stargazers',
#    'contributors_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/contributors',
#    'subscribers_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/subscribers',
#    'subscription_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/subscription',
#    'commits_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/merges',
#    'archive_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/downloads',
#    'issues_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/mitulprajapati/Twitter-Spam-detection/deployments',
#    'created_at': '2020-04-11T07:45:32Z',
#    'updated_at': '2023-07-12T09:30:05Z',
#    'pushed_at': '2020-04-11T07:47:18Z',
#    'git_url': 'git://github.com/mitulprajapati/Twitter-Spam-detection.git',
#    'ssh_url': 'git@github.com:mitulprajapati/Twitter-Spam-detection.git',
#    'clone_url': 'https://github.com/mitulprajapati/Twitter-Spam-detection.git',
#    'svn_url': 'https://github.com/mitulprajapati/Twitter-Spam-detection',
#    'homepage': None,
#    'size': 26,
#    'stargazers_count': 4,
#    'watchers_count': 4,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 4,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 102380052,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMDIzODAwNTI=',
#    'name': 'data-analysis-pandas',
#    'full_name': 'saurabhpati/data-analysis-pandas',
#    'private': False,
#    'owner': {'login': 'saurabhpati',
#     'id': 20544414,
#     'node_id': 'MDQ6VXNlcjIwNTQ0NDE0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/20544414?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/saurabhpati',
#     'html_url': 'https://github.com/saurabhpati',
#     'followers_url': 'https://api.github.com/users/saurabhpati/followers',
#     'following_url': 'https://api.github.com/users/saurabhpati/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/saurabhpati/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/saurabhpati/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/saurabhpati/subscriptions',
#     'organizations_url': 'https://api.github.com/users/saurabhpati/orgs',
#     'repos_url': 'https://api.github.com/users/saurabhpati/repos',
#     'events_url': 'https://api.github.com/users/saurabhpati/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/saurabhpati/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/saurabhpati/data-analysis-pandas',
#    'description': 'A small data analysis project using python - language, matplotlib - data visualization lib, pandas - data processing and Jupyter - Ipython notebook',
#    'fork': False,
#    'url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas',
#    'forks_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/forks',
#    'keys_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/teams',
#    'hooks_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/hooks',
#    'issue_events_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/events',
#    'assignees_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/tags',
#    'blobs_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/languages',
#    'stargazers_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/stargazers',
#    'contributors_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/contributors',
#    'subscribers_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/subscribers',
#    'subscription_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/subscription',
#    'commits_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/merges',
#    'archive_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/downloads',
#    'issues_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/saurabhpati/data-analysis-pandas/deployments',
#    'created_at': '2017-09-04T16:15:05Z',
#    'updated_at': '2024-11-30T08:02:57Z',
#    'pushed_at': '2018-01-25T15:52:46Z',
#    'git_url': 'git://github.com/saurabhpati/data-analysis-pandas.git',
#    'ssh_url': 'git@github.com:saurabhpati/data-analysis-pandas.git',
#    'clone_url': 'https://github.com/saurabhpati/data-analysis-pandas.git',
#    'svn_url': 'https://github.com/saurabhpati/data-analysis-pandas',
#    'homepage': '',
#    'size': 501,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'HTML',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 7,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ipython-notebook', 'matplotlib', 'pandas', 'python-3-6'],
#    'visibility': 'public',
#    'forks': 7,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'master',
#    'score': 1.0}]}
