# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayalakshmi-kothapalli/python_mini_projects/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6b9641b7-ccb0-4b5b-a1b0-1d036b845950" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b9641b7-ccb0-4b5b-a1b0-1d036b845950">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'Credit_Card_Applications.csv': b'CustomerID,A1,A2,A3,A4,A5,A6,A7,A8,A9,A10,A11,A12,A13,A14,Class\r\n15776156,1,22.08,11.46,2,4,4,1.585,0,0,0,1,2,100,1213,0\r\n15739548,0,22.67,7,2,8,4,0.165,0,0,0,0,2,160,1,0\r\n15662854,0,29.58,1.75,1,4,4,1.25,0,0,0,1,2,280,1,0\r\n15687688,0,21.67,11.5,1,5,3,0,1,1,11,1,2,0,1,1\r\n15715750,1,20.17,8.17,2,6,4,1.96,1,1,14,0,2,60,159,1\r\n15571121,0,15.83,0.585,2,8,8,1.5,1,1,2,0,2,100,1,1\r\n15726466,1,17.42,6.5,2,3,4,0.125,0,0,0,0,2,60,101,0\r\n15660390,0,58.67,4.46,2,11,8,3.04,1,1,6,0,2,43,561,1\r\n15663942,1,27.83,1,1,2,8,3,0,0,0,0,2,176,538,0\r\n15638610,0,55.75,7.08,2,4,8,6.75,1,1,3,1,2,100,51,0\r\n15644446,1,33.5,1.75,2,14,8,4.5,1,1,4,1,2,253,858,1\r\n15585892,1,41.42,5,2,11,8,5,1,1,6,1,2,470,1,1\r\n15609356,1,20.67,1.25,1,8,8,1.375,1,1,3,1,2,140,211,0\r\n15803378,1,34.92,5,2,14,8,7.5,1,1,6,1,2,0,1001,1\r\n15599440,1,58.58,2.71,2,8,4,2.415,0,0,0,1,2,320,1,0\r\n15692408,1,48.08,6.04,2,4,4,0.04,0,0,0,0,2,0,2691,1\r\n15683168,1,29.58,4.5,2,9,4,7.5,1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset=pd.read_csv('/content/Credit_Card_Applications.csv')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
#check column names from the dataset
dataset.columns
# Out:
# Index(['CustomerID', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9',
#        'A10', 'A11', 'A12', 'A13', 'A14', 'Class'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
dataset.loc[[0,1,5],['A11','A2','A1']]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
dataset.iloc[[0,1,5],[11,2,1]]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
dataset.loc[1,'A2']=23

# %%
dataset.loc[1,'A2']
# Out:
# 23.0

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
import pandas as pd
df1=pd.DataFrame(idata)

# %%
idata
# Out:
# {'Age': [84,
#   57,
#   90,
#   31,
#   27,
#   59,
#   75,
#   39,
#   89,
#   3,
#   89,
#   3,
#   41,
#   12,
#   7,
#   4,
#   3,
#   66,
#   43,
#   38,
#   85,
#   100,
#   93,
#   91,
#   4,
#   19,
#   68,
#   80,
#   84,
#   56,
#   50,
#   86,
#   51,
#   83,
#   3,
#   25,
#   75,
#   60,
#   59,
#   37,
#   13,
#   12,
#   55,
#   83,
#   8,
#   25,
#   8,
#   81,
#   2,
#   9,
#   8,
#   43,
#   54,
#   35,
#   66,
#   33,
#   78,
#   51,
#   36,
#   10,
#   70,
#   33,
#   35,
#   69,
#   78,
#   52,
#   49,
#   34,
#   63,
#   88,
#   32,
#   67,
#   100,
#   35,
#   95,
#   5,
#   57,
#   64,
#   62,
#   33,
#   0,
#   68,
#   90,
#   19,
#   4,
#   0,
#   41,
#   41,
#   26,
#   17,
#   87,
#   47,
#   17,
#   77,
#   55,
#   63,
#   22,
#   83,
#   78,
#   20],
#  'Height': [45,
#   38,
#   71,
#   55,
#   36,
#   57,
#   15,
#   3,
#   59,
#   81,
#   90,
#   55,
#   61,
#   76,
#   45,
#   2,
#   50,
#   28,
#   16,
#   10,
#   35,
#   91,
#   75,
#   80,
# ...

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    47.550000   52.690000   52.900000   44.650000
# std     29.721391   30.198901   29.087642   28.943475
# min      0.000000    0.000000    1.000000    1.000000
# 25%     21.500000   24.000000   26.000000   20.500000
# 50%     49.500000   57.000000   54.500000   41.500000
# 75%     75.000000   77.250000   79.250000   66.250000
# max    100.000000  100.000000  100.000000   99.000000

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    84      45      49     31
# 1    57      38      81     10
# 2    90      71      73     46
# 3    31      55      58     47
# 4    27      36      45     45
# ..  ...     ...     ...    ...
# 95   63      11      80     86
# 96   22      50      51     10
# 97   83      39      22     10
# 98   78      77      52     99
# 99   20      88      66     78
#
# [100 rows x 4 columns]

# %%
df1['Weight']>50
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 95     True
# 96     True
# 97    False
# 98     True
# 99     True
# Name: Weight, Length: 100, dtype: bool

# %%
filter1=df1['Weight']>50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    57      38      81     10
# 2    90      71      73     46
# 3    31      55      58     47
# 5    59      57      81     35
# 6    75      15      85     35
# 10   89      90      80     52
# 11    3      55      93     82
# 12   41      61      93     14
# 15    4       2      58      5
# 16    3      50      96      8
# 17   66      28      51     44
# 18   43      16      69     71
# 19   38      10      74     37
# 20   85      35      63     21
# 22   93      75      94     78
# 25   19      99      79      1
# 26   68      16      92     27
# 27   80      57      53     57
# 36   75      83      88      7
# 37   60      57      66     93
# 44    8      99      82     59
# 46    8      35      65      8
# 47   81      94      93     84
# 50    8       5      91     10
# 51   43      52      63     85
# 54   66      52      74     37
# 56   78      18      81     90
# 57   51      73      90     57
# 58   36      74      60     95
# ...

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    57      38      81     10
# 2    90      71      73     46
# 3    31      55      58     47
# 5    59      57      81     35
# 6    75      15      85     35
# 10   89      90      80     52
# 11    3      55      93     82
# 12   41      61      93     14
# 15    4       2      58      5
# 16    3      50      96      8
# 17   66      28      51     44
# 18   43      16      69     71
# 19   38      10      74     37
# 20   85      35      63     21
# 22   93      75      94     78
# 25   19      99      79      1
# 26   68      16      92     27
# 27   80      57      53     57
# 36   75      83      88      7
# 37   60      57      66     93
# 44    8      99      82     59
# 46    8      35      65      8
# 47   81      94      93     84
# 50    8       5      91     10
# 51   43      52      63     85
# 54   66      52      74     37
# 56   78      18      81     90
# 57   51      73      90     57
# 58   36      74      60     95
# ...

# %%
filter2=df1['Age']>50

# %%
df1[filter1|filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    84      45      49     31
# 1    57      38      81     10
# 2    90      71      73     46
# 3    31      55      58     47
# 5    59      57      81     35
# ..  ...     ...     ...    ...
# 95   63      11      80     86
# 96   22      50      51     10
# 97   83      39      22     10
# 98   78      77      52     99
# 99   20      88      66     78
#
# [73 rows x 4 columns]

# %%
df1.loc[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    57      38      81     10
# 2    90      71      73     46
# 5    59      57      81     35
# 6    75      15      85     35
# 10   89      90      80     52
# 17   66      28      51     44
# 20   85      35      63     21
# 22   93      75      94     78
# 26   68      16      92     27
# 27   80      57      53     57
# 36   75      83      88      7
# 37   60      57      66     93
# 47   81      94      93     84
# 54   66      52      74     37
# 56   78      18      81     90
# 57   51      73      90     57
# 60   70      29      59     85
# 68   63      88      97     48
# 69   88       6      69     63
# 71   67      50      70     66
# 72  100      73      85     85
# 76   57      68      56     60
# 77   64      65      64      8
# 78   62      69      94     88
# 82   90      96      78      2
# 90   87      86      69     57
# 93   77      13      87     63
# 94   55      98      77     63
# 95   63      11      80     86
# ...
